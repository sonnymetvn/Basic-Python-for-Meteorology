# %%
from IPython.display import Image
Image('mat08.png')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
mpl.rcParams['font.family'] = 'serif'

# %% [markdown]
# - Here is the reference link to learn more:
# https://matplotlib.org/3.1.0/api/axes_api.html

# %%
from IPython.display import Image
Image('12_06_matplotlib_axis.png')

# %%
from IPython.display import Image
Image('12_07_xy_ticks.png')

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)
y = np.sin(x) * np.sin(2*x) * np.exp(-x**1/5)

# %%
# create some artificial data
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

x_major_ticker = mpl.ticker.MultipleLocator(2)
y_major_ticker = mpl.ticker.MultipleLocator(0.5)
x_minor_ticker = mpl.ticker.MultipleLocator(1)
y_minor_ticker = mpl.ticker.MultipleLocator(0.25)

for ax in axes:
    ax.plot(x, y, lw=3, c='m')
    ax.xaxis.set_major_locator(x_major_ticker)
    ax.yaxis.set_major_locator(y_major_ticker)
    ax.xaxis.set_minor_locator(x_minor_ticker)
    ax.yaxis.set_minor_locator(y_minor_ticker)

# 1st figure
axes[0].set_title('default grid')
axes[0].grid()

# 2nd figure
axes[1].set_title('major and minor grid')
axes[1].grid(color='blue', which='both', linestyle=':', linewidth=0.5)

# 3rd figure
axes[2].set_title("individual x/y major/minor grid")
axes[2].grid(color='grey', which='major', axis='x', linestyle='-', linewidth=0.5)
axes[2].grid(color='red' , which='minor', axis='x', linestyle=':', linewidth=1.0)
axes[2].grid(color='blue', which='major', axis='y', linestyle='-', linewidth=2.5)

fig.tight_layout()

# %% [markdown]
# ## All done !!!
# - Please feel free to let me know if there is any questions
# - Please subscribe my youtube channel too
# - Thank you very much
